# %%
from ebsco import scrapeRawData
from jhu_covid19 import buildGlobalSum
import os

slash = os.path.sep
# scrapeRawData
path = "ebsco"+slash+"rawData.xml"
entries = scrapeRawData.scrapeRawData(path, "COVID-19");
scrapeRawData.writeCSV('csvData.csv', entries);
print("scraped ", len(entries), " publications")

dailyCount = scrapeRawData.buildDailyPublishCount(entries)
scrapeRawData.plotDayData(dailyCount, 
            ylabel = "No. publications per day", 
            title = "COVID-19 Publications per Day", 
            todayCol = 'r', 
            maxCol = 'b', 
            fmt = 'go',
            saveFmt = 'svg')

dailySum = scrapeRawData.buildDailyPublishSum(dailyCount)
scrapeRawData.plotDayData(dailySum, 
            ylabel = "Total publications", 
            title = "COVID-19 Total Publications", 
            todayCol = 'r', 
            maxCol = 'b', 
            fmt = '|g-',
            saveFmt = 'svg')

# buildGlobalSum

path = os.getcwd()+slash+"jhu_covid19"+slash+"COVID-19"+slash+"csse_covid_19_data"+slash+"csse_covid_19_time_series"+slash
df = buildGlobalSum.buildGlobalSum()
print(df)
# Out:
# scraped  2196  publications
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-3d306dee1add> in <module>
#      28
#      29 # buildGlobalSum
# ---> 30 df = buildGlobalSum.buildGlobalSum()
#      31 print(df)
#
# ~\Desktop\School\Spring 20\Health Economics\COVID19AcademiaDataset\jhu_covid19\buildGlobalSum.py in buildGlobalSum()
#      24
#      25     # Read JHU csv's into pandas dataframes
# ---> 26     cDf = pd.read_csv(cPath)
#      27     dDf = pd.read_csv(dPath)
#      28     rDf = pd.read_csv(rPath)
#
# ...
